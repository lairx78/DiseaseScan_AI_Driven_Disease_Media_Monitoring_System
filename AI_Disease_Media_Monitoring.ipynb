# %%
# !pip install langgraph
# !pip install -qU "langchain[google-vertexai]"
# !pip install python-docx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import ai_disease_media_monitoring
from ai_disease_media_monitoring import AI_Disease_Media_Monitoring
# Out:
# Using model: gemini-2.5-flash-preview-04-17
# Using model for tools: gemini-2.0-flash
# Initialized LLMs.
# Using native .with_structured_output() with the classification LLM.

# %%
AI_Disease_Media_Monitoring("all_new.xlsx", db_to_excel=True, db_name="/content/etl.db", agent_message=False)
# Out:
# Database and table 'articles' created successfully.
#     id disease_related                                      article_title  \
# 0    1             yes                                     1996 - Liberia
# 1    2             yes  UKHSA publishes first annual report summarisin...
# 2    3             yes                  Zika Risks Continue in March 2025
# 3    4             yes  Hong Kong government staff among 57 food poiso...
# 4    5             yes  US respiratory virus levels remain high as flu...
# 5    6             yes  CDC updates and simplifies respiratory virus r...
# 6    7             yes  New single-dose dengue vaccine shows 80% prote...
# 7    8             yes  Clinical trial confirms efficacy, safety of lo...
# 8    9             yes  CDC: Acute flaccid myelitis cases low since 20...
# 9   10             yes  Import of poultry meat and products from areas...
# 10  11             yes        Maryland and Ohio confirm new measles cases
# ...

# %%
# !zip -r /content/file.zip /content/20250501_113845
# Out:
#   adding: content/20250501_113845/ (stored 0%)
#   adding: content/20250501_113845/communicable_disease_report_da5c591ececa4b91b2bbb68e1e55af7f.docx (deflated 7%)
#   adding: content/20250501_113845/communicable_disease_report_7111e16ea2ce412e97ee470a83a73340.docx (deflated 7%)
#   adding: content/20250501_113845/communicable_disease_report_9301fb6be833420ab835889775668c07.docx (deflated 7%)
#   adding: content/20250501_113845/communicable_disease_report_598a69ff34554ba7a5c88253e33e3a40.docx (deflated 7%)
#   adding: content/20250501_113845/etl.xlsx (deflated 5%)
#   adding: content/20250501_113845/communicable_disease_report_1b5ec3add4d94d2aba534b3f9198ee3f.docx (deflated 7%)
#   adding: content/20250501_113845/communicable_disease_report_4c0f30d043774f63a03a5b819a684532.docx (deflated 7%)
#   adding: content/20250501_113845/communicable_disease_report_77d3f9a7c7534d96a15e88ac6280feab.docx (deflated 7%)
# ...
